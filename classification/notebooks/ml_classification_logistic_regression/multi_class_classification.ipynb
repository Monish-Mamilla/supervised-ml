# %% [markdown]
# Logistic Regression - sigmoid = 1/1+e**-z  (e is Eler's number ~ 2.71828)  , z = b0 = b1x1  , we can replace z value in the sigmoid
# We will use SKLean for the Binary Classification using LogisticRegression

# %% [markdown]
# <h2> Multi Class Classification using Iris Dataset </h2>

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import load_iris

iris = load_iris(as_frame=True)
df = iris.frame

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
df.target.unique()
# Out:
# array([0, 1, 2])

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
print(iris.keys())
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %% [markdown]
# <h3> Data Visulization <h3>

# %%
X = df[['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
       'petal width (cm)']]
y = df['target']

# %%
X.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
X_test
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 73                 6.1               2.8                4.7               1.2
# 18                 5.7               3.8                1.7               0.3
# 118                7.7               2.6                6.9               2.3
# 78                 6.0               2.9                4.5               1.5
# 76                 6.8               2.8                4.8               1.4
# 31                 5.4               3.4                1.5               0.4
# 64                 5.6               2.9                3.6               1.3
# 141                6.9               3.1                5.1               2.3
# 68                 6.2               2.2                4.5               1.5
# 82                 5.8               2.7                3.9               1.2
# 110                6.5               3.2                5.1               2.0
# 12                 4.8               3.0                1.4               0.1
# 36                 5.5               3.5                1.3               0.2
# 9                  4.9               3.1                1.5               0.1
# 19                 5.1               3.8                1.5               0.3
# 56                 6.3               3.3                4.7               1.6
# 104                6.5               3.0                5.8               2.2
# 69                 5.6               2.5                3.9               1.1
# 55                 5.7               2.8                4.5               1.3
# 132                6.4               2.8                5.6               2.2
# 29                 4.7               3.2                1.6               0.2
# 127                6.1               3.0                4.9               1.8
# 26                 5.0               3.4                1.6               0.4
# 128                6.4               2.8                5.6               2.1
# 131                7.9               3.8                6.4               2.0
# 145                6.7               3.0                5.2               2.3
# 108                6.7               2.5                5.8               1.8
# 143                6.8               3.2                5.9               2.3
# 45                 4.8               3.0                1.4               0.3
# 30                 4.8               3.1                1.6               0.2
# 22                 4.6               3.6                1.0               0.2
# 15                 5.7               4.4                1.5               0.4
# 65                 6.7               3.1                4.4               1.4
# 11                 4.8               3.4                1.6               0.2
# 42                 4.4               3.2                1.3               0.2
# 146                6.3               2.5                5.0               1.9
# 51                 6.4               3.2                4.5               1.5
# 27                 5.2               3.5                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# 32                 5.2               4.1                1.5               0.1
# 142                5.8               2.7                5.1               1.9
# 85                 6.0               3.4                4.5               1.6
# 86                 6.7               3.1                4.7               1.5
# 16                 5.4               3.9                1.3               0.4
# 10                 5.4               3.7                1.5               0.2

# %%
y_test
# Out:
# 73     1
# 18     0
# 118    2
# 78     1
# 76     1
# 31     0
# 64     1
# 141    2
# 68     1
# 82     1
# 110    2
# 12     0
# 36     0
# 9      0
# 19     0
# 56     1
# 104    2
# 69     1
# 55     1
# 132    2
# 29     0
# 127    2
# 26     0
# 128    2
# 131    2
# 145    2
# 108    2
# 143    2
# 45     0
# 30     0
# 22     0
# 15     0
# 65     1
# 11     0
# 42     0
# 146    2
# 51     1
# 27     0
# 4      0
# 32     0
# 142    2
# 85     1
# 86     1
# 16     0
# 10     0
# Name: target, dtype: int64

# %%
y_pred = model.predict(X_test)

# %%
model.predict_proba(X_test)
# Out:
# array([[4.09968171e-03, 8.12343785e-01, 1.83556533e-01],
#        [9.41955383e-01, 5.80440364e-02, 5.80207091e-07],
#        [1.58411194e-08, 2.09129801e-03, 9.97908686e-01],
#        [6.82489380e-03, 7.73251390e-01, 2.19923716e-01],
#        [1.59400337e-03, 7.51205955e-01, 2.47200042e-01],
#        [9.50040951e-01, 4.99585899e-02, 4.58821932e-07],
#        [7.78024886e-02, 9.04145035e-01, 1.80524761e-02],
#        [1.79835671e-04, 1.47357834e-01, 8.52462330e-01],
#        [2.42255639e-03, 7.80452684e-01, 2.17124759e-01],
#        [2.89983092e-02, 9.40818587e-01, 3.01831039e-02],
#        [4.73569169e-04, 2.25282308e-01, 7.74244123e-01],
#        [9.62693727e-01, 3.73060892e-02, 1.84138818e-07],
#        [9.69162381e-01, 3.08375221e-02, 9.66515195e-08],
#        [9.56006776e-01, 4.39929587e-02, 2.65383960e-07],
#        [9.76521686e-01, 2.34781248e-02, 1.89459860e-07],
#        [4.76686019e-03, 6.63398557e-01, 3.31834583e-01],
#        [9.67225286e-06, 2.67217939e-02, 9.73268534e-01],
#        [2.76880629e-02, 9.45164487e-01, 2.71474497e-02],
#        [8.70363695e-03, 8.20159507e-01, 1.71136856e-01],
#        [1.93849410e-05, 4.14384542e-02, 9.58542161e-01],
#        [9.58706180e-01, 4.12933664e-02, 4.53338699e-07],
#        [1.43040406e-03, 3.86686167e-01, 6.11883429e-01],
#        [9.56268855e-01, 4.37304985e-02, 6.46632927e-07],
#        [2.49482599e-05, 5.20895240e-02, 9.47885528e-01],
#        [1.75965912e-06, 2.03683471e-02, 9.79629893e-01],
#        [1.09767417e-04, 1.05450748e-01, 8.94439484e-01],
#        [1.25230348e-05, 6.98143160e-02, 9.30173161e-01],
#        [5.51876304e-06, 1.94870602e-02, 9.80507421e-01],
#        [9.60964456e-01, 3.90352329e-02, 3.11334135e-07],
#        [9.49468760e-01, 5.05307070e-02, 5.32556231e-07],
#        [9.93198826e-01, 6.80115830e-03, 1.52784543e-08],
#        [9.80688635e-01, 1.93112310e-02, 1.34390488e-07],
#        [6.90525896e-03, 8.90002162e-01, 1.03092579e-01],
#        [9.64649477e-01, 3.53501631e-02, 3.59480866e-07],
#        [9.82596845e-01, 1.74030540e-02, 1.00986801e-07],
#        [3.77084978e-04, 2.85211234e-01, 7.14411682e-01],
#        [7.34556524e-03, 8.12169256e-01, 1.80485179e-01],
#        [9.64124055e-01, 3.58757208e-02, 2.23908384e-07],
#        [9.78096005e-01, 2.19038799e-02, 1.15138896e-07],
#        [9.83059932e-01, 1.69399907e-02, 7.74335625e-08],
#        [4.12802160e-04, 1.94047653e-01, 8.05539545e-01],
#        [1.18346757e-02, 7.37092682e-01, 2.51072642e-01],
#        [3.04246398e-03, 7.51662946e-01, 2.45294590e-01],
#        [9.81752132e-01, 1.82477747e-02, 9.28859720e-08],
#        [9.66610415e-01, 3.33894021e-02, 1.83110211e-07]])

# %% [markdown]
# ### Model Evaluation

# %%
from sklearn.metrics import classification_report

report = classification_report(y_test,y_pred)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
